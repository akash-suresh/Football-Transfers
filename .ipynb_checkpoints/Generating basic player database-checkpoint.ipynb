# %%
#Code to get Player database from api.football-data.org

# %%
import httplib
import bs4
import json
from wikipedia import *
from re import *
from bs4 import *
from pandas import *

# %%
#opens initialized empty csv file!

db = read_csv('database.csv')
db
z=0

# %%
db
# Out:
#         Name  Club  Market Value  Jersey Number  Date of Birth  \
# 0        NaN   NaN           NaN            NaN            NaN
# 1        NaN   NaN           NaN            NaN            NaN
# 2        NaN   NaN           NaN            NaN            NaN
# 3        NaN   NaN           NaN            NaN            NaN
# 4        NaN   NaN           NaN            NaN            NaN
# 5        NaN   NaN           NaN            NaN            NaN
# 6        NaN   NaN           NaN            NaN            NaN
# 7        NaN   NaN           NaN            NaN            NaN
# 8        NaN   NaN           NaN            NaN            NaN
# 9        NaN   NaN           NaN            NaN            NaN
# 10       NaN   NaN           NaN            NaN            NaN
# 11       NaN   NaN           NaN            NaN            NaN
# 12       NaN   NaN           NaN            NaN            NaN
# 13       NaN   NaN           NaN            NaN            NaN
# ...

# %%
connection = httplib.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': 'bc608ba18f034f468ab0d65ad7b9fceb', 'X-Response-Control': 'minified' }
connection.request('GET', '/v1/soccerseasons/398/teams', None, headers )
response = json.loads(connection.getresponse().read())

for i in response['teams']:
    id1=i['id']
    name=i['name']
    #market=i['marketValue']
    print "TEAM NAME : ",name+"\n**\t**\n"
    connection1=httplib.HTTPConnection('api.football-data.org')
    headers1={'X-Auth-Token':'bc608ba18f034f468ab0d65ad7b9fceb' , 'X-Response-Control':'minified'}
    connection1.request('GET','/v1/teams/'+str(id1)+'/players',None,headers1)
    response1=json.loads(connection1.getresponse().read())
    for j in response1['players']:
        print j
        db['Name'][z]=j['name']
        db['Market Value'][z]=j['marketValue']
        db['Club'][z]=name
        db['Jersey Number'][z]=j['jerseyNumber']
        db['Date of Birth'][z]=j['dateOfBirth']
        db['Contract until'][z]=j['contractUntil']
        db['Nationality'][z]=j['nationality']
        db['Position'][z]=j['position']
        db['id'][z]=j['id']
        z = z + 1
# Out:
# TEAM NAME :  Manchester United FC
# **	**
#
# {u'name': u'Bastian Schweinsteiger', u'marketValue': u'22,000,000 \u20ac', u'jerseyNumber': 31, u'dateOfBirth': u'1984-08-01', u'contractUntil': u'2018-06-30', u'nationality': u'Germany', u'position': u'Central Midfield', u'id': 16}
# /home/akash/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/akash/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/akash/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:19: SettingWithCopyWarning:
# ...

# %%
print db
# Out:
#                          Name                  Club  Market Value  \
# 0      Bastian Schweinsteiger  Manchester United FC  22,000,000 €
# 1                David de Gea  Manchester United FC  30,000,000 €
# 2                  Phil Jones  Manchester United FC  15,000,000 €
# 3                 Marcos Rojo  Manchester United FC  18,000,000 €
# 4              Chris Smalling  Manchester United FC  14,000,000 €
# 5              Patrick McNair  Manchester United FC   4,500,000 €
# 6                   Luke Shaw  Manchester United FC  21,000,000 €
# 7                 Daley Blind  Manchester United FC  17,000,000 €
# 8             Michael Carrick  Manchester United FC   4,000,000 €
# 9               Ander Herrera  Manchester United FC  28,000,000 €
# 10          Marouane Fellaini  Manchester United FC  20,000,000 €
# 11                  Juan Mata  Manchester United FC  34,000,000 €
# 12              Jesse Lingard  Manchester United FC   1,000,000 €
# ...

# %%
db.to_csv('Database.csv')
